# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 763

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]      
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')    
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | sao joao da barra
# Processing Record 3 of Set 1 | oranjemund
# Processing Record 4 of Set 1 | lagoa
# Processing Record 5 of Set 1 | mataura
# Processing Record 6 of Set 1 | qaanaaq
# Processing Record 7 of Set 1 | wagar
# Processing Record 8 of Set 1 | tabou
# Processing Record 9 of Set 1 | bluff
# Processing Record 10 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 1 | barrow
# Processing Record 12 of Set 1 | santa teresa
# Processing Record 13 of Set 1 | araouane
# Processing Record 14 of Set 1 | hambantota
# Processing Record 15 of Set 1 | richards bay
# Processing Record 16 of Set 1 | lasa
# Processing Record 17 of Set 1 | atuona
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | oyama
# Processing Record 20 of Set 1 | port macquarie
# Processing Record 21 of Set 1 | namibe
# Processing Record 22 of Set 1 | mar del plata
# Processing Record 23 of Set 1 | boke
# Processing Record 24 of Set 1 | san patricio
# Processing Record 25 of Set 1 | pisco
# Processing Record 26 of Set 1 | yomou
# Processing Record 27 of Set 1 | harper
# Processing Record 28 of Set 1 | hobart
# Processing Record 29 of Set 1 | christchurch
# Processing Record 30 of Set 1 | juneau
# Processing Record 31 of Set 1 | caravelas
# Processing Record 32 of Set 1 | grand gaube
# Processing Record 33 of Set 1 | jamestown
# Processing Record 34 of Set 1 | margate
# Processing Record 35 of Set 1 | tasiilaq
# Processing Record 36 of Set 1 | ushuaia
# Processing Record 37 of Set 1 | witney
# Processing Record 38 of Set 1 | oussouye
# Processing Record 39 of Set 1 | puerto ayora
# Processing Record 40 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 1 | norman wells
# Processing Record 42 of Set 1 | bengkulu
# Processing Record 43 of Set 1 | hovd
# Processing Record 44 of Set 1 | ferkessedougou
# Processing Record 45 of Set 1 | saskylakh
# Processing Record 46 of Set 1 | nyurba
# Processing Record 47 of Set 1 | bonfim
# Processing Record 48 of Set 1 | longyearbyen
# Processing Record 49 of Set 1 | cape town
# Processing Record 50 of Set 1 | zhongshan
# Processing Record 1 of Set 2 | pinega
# Processing Record 2 of Set 2 | guane
# Processing Record 3 of Set 2 | rujewa
# Processing Record 4 of Set 2 | punta arenas
# Processing Record 5 of Set 2 | greencastle
# Processing Record 6 of Set 2 | kapaa
# Processing Record 7 of Set 2 | salta
# Processing Record 8 of Set 2 | lorengau
# Processing Record 9 of Set 2 | boguchany
# Processing Record 10 of Set 2 | ribeira grande
# Processing Record 11 of Set 2 | darhan
# Processing Record 12 of Set 2 | thompson
# Processing Record 13 of Set 2 | baykit
# Processing Record 14 of Set 2 | laguna
# Processing Record 15 of Set 2 | saldanha
# Processing Record 16 of Set 2 | abadan
# Processing Record 17 of Set 2 | nikolskoye
# Processing Record 18 of Set 2 | bandarbeyla
# Processing Record 19 of Set 2 | kodiak
# Processing Record 20 of Set 2 | hithadhoo
# Processing Record 21 of Set 2 | bredasdorp
# Processing Record 22 of Set 2 | khatanga
# Processing Record 23 of Set 2 | alta floresta
# Processing Record 24 of Set 2 | cap malheureux
# Processing Record 25 of Set 2 | atikokan
# Processing Record 26 of Set 2 | east london
# Processing Record 27 of Set 2 | redcar
# Processing Record 28 of Set 2 | hobyo
# Processing Record 29 of Set 2 | prado
# Processing Record 30 of Set 2 | burica
# City not found. Skipping...
# Processing Record 31 of Set 2 | trairi
# Processing Record 32 of Set 2 | saint-philippe
# Processing Record 33 of Set 2 | arraial do cabo
# Processing Record 34 of Set 2 | ostrovnoy
# Processing Record 35 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 36 of Set 2 | constantine
# Processing Record 37 of Set 2 | hilo
# Processing Record 38 of Set 2 | carnarvon
# Processing Record 39 of Set 2 | sao filipe
# Processing Record 40 of Set 2 | ngunguru
# Processing Record 41 of Set 2 | lebu
# Processing Record 42 of Set 2 | taltal
# Processing Record 43 of Set 2 | whitehorse
# Processing Record 44 of Set 2 | puri
# Processing Record 45 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 2 | yulara
# Processing Record 47 of Set 2 | marawi
# Processing Record 48 of Set 2 | busselton
# Processing Record 49 of Set 2 | tuatapere
# Processing Record 50 of Set 2 | mbandaka
# Processing Record 1 of Set 3 | flinders
# Processing Record 2 of Set 3 | hermanus
# Processing Record 3 of Set 3 | port alfred
# Processing Record 4 of Set 3 | malartic
# Processing Record 5 of Set 3 | espana
# Processing Record 6 of Set 3 | ilulissat
# Processing Record 7 of Set 3 | listvyanskiy
# Processing Record 8 of Set 3 | severo-kurilsk
# Processing Record 9 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 3 | castro
# Processing Record 11 of Set 3 | fredericksburg
# Processing Record 12 of Set 3 | jumla
# Processing Record 13 of Set 3 | torbay
# Processing Record 14 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 15 of Set 3 | constitucion
# Processing Record 16 of Set 3 | manitouwadge
# Processing Record 17 of Set 3 | horana
# Processing Record 18 of Set 3 | upernavik
# Processing Record 19 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of Set 3 | hamilton
# Processing Record 21 of Set 3 | pokhara
# Processing Record 22 of Set 3 | unai
# Processing Record 23 of Set 3 | shubarkuduk
# Processing Record 24 of Set 3 | urusha
# Processing Record 25 of Set 3 | broken hill
# Processing Record 26 of Set 3 | mokhsogollokh
# Processing Record 27 of Set 3 | kruisfontein
# Processing Record 28 of Set 3 | raahe
# Processing Record 29 of Set 3 | petrolandia
# City not found. Skipping...
# Processing Record 30 of Set 3 | tombouctou
# Processing Record 31 of Set 3 | new norfolk
# Processing Record 32 of Set 3 | nabire
# Processing Record 33 of Set 3 | avarua
# Processing Record 34 of Set 3 | komsomolskiy
# Processing Record 35 of Set 3 | sao jose da coroa grande
# Processing Record 36 of Set 3 | necochea
# Processing Record 37 of Set 3 | adrar
# Processing Record 38 of Set 3 | kommunisticheskiy
# Processing Record 39 of Set 3 | laredo
# Processing Record 40 of Set 3 | kawalu
# Processing Record 41 of Set 3 | vieux-habitants
# Processing Record 42 of Set 3 | novyy urgal
# Processing Record 43 of Set 3 | abu zabad
# Processing Record 44 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 3 | bakel
# Processing Record 47 of Set 3 | te anau
# Processing Record 48 of Set 3 | nome
# Processing Record 49 of Set 3 | hami
# Processing Record 50 of Set 3 | kumluca
# Processing Record 1 of Set 4 | cravo norte
# Processing Record 2 of Set 4 | garissa
# Processing Record 3 of Set 4 | atessa
# Processing Record 4 of Set 4 | cabo san lucas
# Processing Record 5 of Set 4 | dikson
# Processing Record 6 of Set 4 | georgetown
# Processing Record 7 of Set 4 | port moresby
# Processing Record 8 of Set 4 | ufimskiy
# Processing Record 9 of Set 4 | manama
# Processing Record 10 of Set 4 | borovskoy
# Processing Record 11 of Set 4 | yellowknife
# Processing Record 12 of Set 4 | olinda
# Processing Record 13 of Set 4 | meteti
# Processing Record 14 of Set 4 | leningradskiy
# Processing Record 15 of Set 4 | chuy
# Processing Record 16 of Set 4 | esperance
# Processing Record 17 of Set 4 | dondo
# Processing Record 18 of Set 4 | szczytno
# Processing Record 19 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 4 | westport
# Processing Record 21 of Set 4 | sola
# Processing Record 22 of Set 4 | dillon
# Processing Record 23 of Set 4 | taoudenni
# Processing Record 24 of Set 4 | sao felix do xingu
# Processing Record 25 of Set 4 | mecca
# Processing Record 26 of Set 4 | mana
# Processing Record 27 of Set 4 | kapoeta
# Processing Record 28 of Set 4 | san quintin
# Processing Record 29 of Set 4 | luderitz
# Processing Record 30 of Set 4 | butler
# Processing Record 31 of Set 4 | sobolevo
# Processing Record 32 of Set 4 | butaritari
# Processing Record 33 of Set 4 | evensk
# Processing Record 34 of Set 4 | korla
# Processing Record 35 of Set 4 | lubango
# Processing Record 36 of Set 4 | faya
# Processing Record 37 of Set 4 | fortuna
# Processing Record 38 of Set 4 | kysyl-syr
# Processing Record 39 of Set 4 | ucar
# Processing Record 40 of Set 4 | la asuncion
# Processing Record 41 of Set 4 | pevek
# Processing Record 42 of Set 4 | camacha
# Processing Record 43 of Set 4 | victoria
# Processing Record 44 of Set 4 | half moon bay
# Processing Record 45 of Set 4 | zhigansk
# Processing Record 46 of Set 4 | mlonggo
# Processing Record 47 of Set 4 | charyshskoye
# Processing Record 48 of Set 4 | mayo
# Processing Record 49 of Set 4 | san luis
# Processing Record 50 of Set 4 | havre-saint-pierre
# Processing Record 1 of Set 5 | mahadday weyne
# City not found. Skipping...
# Processing Record 2 of Set 5 | dunedin
# Processing Record 3 of Set 5 | porto walter
# Processing Record 4 of Set 5 | escanaba
# Processing Record 5 of Set 5 | bethel
# Processing Record 6 of Set 5 | jalu
# Processing Record 7 of Set 5 | airai
# Processing Record 8 of Set 5 | chicama
# Processing Record 9 of Set 5 | sivaki
# Processing Record 10 of Set 5 | abu dhabi
# Processing Record 11 of Set 5 | mango
# Processing Record 12 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 5 | atar
# Processing Record 15 of Set 5 | fairbanks
# Processing Record 16 of Set 5 | whitley bay
# Processing Record 17 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 18 of Set 5 | kashi
# Processing Record 19 of Set 5 | yoichi
# Processing Record 20 of Set 5 | den helder
# Processing Record 21 of Set 5 | sassandra
# Processing Record 22 of Set 5 | kahului
# Processing Record 23 of Set 5 | iskateley
# Processing Record 24 of Set 5 | kaitangata
# Processing Record 25 of Set 5 | sidi ali
# Processing Record 26 of Set 5 | dwarka
# Processing Record 27 of Set 5 | ariquemes
# Processing Record 28 of Set 5 | la ronge
# Processing Record 29 of Set 5 | zhuozhou
# City not found. Skipping...
# Processing Record 30 of Set 5 | varna
# Processing Record 31 of Set 5 | andarab
# City not found. Skipping...
# Processing Record 32 of Set 5 | kristiinankaupunki
# Processing Record 33 of Set 5 | fare
# Processing Record 34 of Set 5 | zhangye
# Processing Record 35 of Set 5 | qasigiannguit
# Processing Record 36 of Set 5 | hualmay
# Processing Record 37 of Set 5 | aykhal
# Processing Record 38 of Set 5 | tuktoyaktuk
# Processing Record 39 of Set 5 | mogadishu
# Processing Record 40 of Set 5 | lakes entrance
# Processing Record 41 of Set 5 | naples
# Processing Record 42 of Set 5 | dryden
# Processing Record 43 of Set 5 | cabra
# Processing Record 44 of Set 5 | san carlos de bariloche
# Processing Record 45 of Set 5 | vastervik
# City not found. Skipping...
# Processing Record 46 of Set 5 | bathsheba
# Processing Record 47 of Set 5 | tessalit
# Processing Record 48 of Set 5 | sinazongwe
# Processing Record 49 of Set 5 | puerto suarez
# Processing Record 50 of Set 5 | weinan
# Processing Record 1 of Set 6 | caconda
# Processing Record 2 of Set 6 | banjarmasin
# Processing Record 3 of Set 6 | guerrero negro
# Processing Record 4 of Set 6 | yuksekova
# Processing Record 5 of Set 6 | tokur
# Processing Record 6 of Set 6 | la plata
# Processing Record 7 of Set 6 | jiblah
# Processing Record 8 of Set 6 | belmonte
# Processing Record 9 of Set 6 | svetlyy
# Processing Record 10 of Set 6 | kesinga
# Processing Record 11 of Set 6 | barcelos
# Processing Record 12 of Set 6 | pendleton
# Processing Record 13 of Set 6 | cidreira
# Processing Record 14 of Set 6 | viedma
# Processing Record 15 of Set 6 | narsaq
# Processing Record 16 of Set 6 | mahebourg
# Processing Record 17 of Set 6 | iqaluit
# Processing Record 18 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 19 of Set 6 | solovetskiy
# City not found. Skipping...
# Processing Record 20 of Set 6 | geraldton
# Processing Record 21 of Set 6 | palmer
# Processing Record 22 of Set 6 | vaini
# Processing Record 23 of Set 6 | gizo
# Processing Record 24 of Set 6 | sauda
# Processing Record 25 of Set 6 | maniitsoq
# Processing Record 26 of Set 6 | rassvet
# Processing Record 27 of Set 6 | cayenne
# Processing Record 28 of Set 6 | bairiki
# Processing Record 29 of Set 6 | benguela
# Processing Record 30 of Set 6 | mayumba
# Processing Record 31 of Set 6 | nakhon phanom
# Processing Record 32 of Set 6 | sterling
# Processing Record 33 of Set 6 | cambui
# Processing Record 34 of Set 6 | kuryk
# Processing Record 35 of Set 6 | katsuura
# Processing Record 36 of Set 6 | bambous virieux
# Processing Record 37 of Set 6 | umm kaddadah
# Processing Record 38 of Set 6 | fort nelson
# Processing Record 39 of Set 6 | high level
# Processing Record 40 of Set 6 | banepa
# Processing Record 41 of Set 6 | rio brilhante
# Processing Record 42 of Set 6 | conceicao da barra
# Processing Record 43 of Set 6 | dromolaxia
# Processing Record 44 of Set 6 | terney
# Processing Record 45 of Set 6 | samarai
# Processing Record 46 of Set 6 | stutterheim
# Processing Record 47 of Set 6 | le port
# Processing Record 48 of Set 6 | bannu
# Processing Record 49 of Set 6 | kropotkin
# Processing Record 50 of Set 6 | asau
# Processing Record 1 of Set 7 | kalabo
# Processing Record 2 of Set 7 | kavieng
# Processing Record 3 of Set 7 | bud
# Processing Record 4 of Set 7 | rawson
# Processing Record 5 of Set 7 | brooks
# Processing Record 6 of Set 7 | ahipara
# Processing Record 7 of Set 7 | ballina
# Processing Record 8 of Set 7 | san policarpo
# Processing Record 9 of Set 7 | mount gambier
# Processing Record 10 of Set 7 | luanda
# Processing Record 11 of Set 7 | ponta do sol
# Processing Record 12 of Set 7 | numan
# Processing Record 13 of Set 7 | ocos
# Processing Record 14 of Set 7 | kitakata
# Processing Record 15 of Set 7 | taveta
# Processing Record 16 of Set 7 | nipawin
# Processing Record 17 of Set 7 | college
# Processing Record 18 of Set 7 | karratha
# Processing Record 19 of Set 7 | inderborskiy
# City not found. Skipping...
# Processing Record 20 of Set 7 | vila franca do campo
# Processing Record 21 of Set 7 | grindavik
# Processing Record 22 of Set 7 | basqal
# Processing Record 23 of Set 7 | bowen
# Processing Record 24 of Set 7 | sitka
# Processing Record 25 of Set 7 | san rafael
# Processing Record 26 of Set 7 | srednekolymsk
# Processing Record 27 of Set 7 | krutinka
# Processing Record 28 of Set 7 | skalistyy
# City not found. Skipping...
# Processing Record 29 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 30 of Set 7 | ancud
# Processing Record 31 of Set 7 | severnyy-kospashskiy
# Processing Record 32 of Set 7 | poum
# Processing Record 33 of Set 7 | great yarmouth
# Processing Record 34 of Set 7 | noumea
# Processing Record 35 of Set 7 | ventspils
# Processing Record 36 of Set 7 | souillac
# Processing Record 37 of Set 7 | gamba
# Processing Record 38 of Set 7 | port elizabeth
# Processing Record 39 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 40 of Set 7 | labuhan
# Processing Record 41 of Set 7 | ukiah
# Processing Record 42 of Set 7 | saint-jean-de-maurienne
# Processing Record 43 of Set 7 | pangai
# Processing Record 44 of Set 7 | maceio
# Processing Record 45 of Set 7 | kerema
# Processing Record 46 of Set 7 | isangel
# Processing Record 47 of Set 7 | bad nauheim
# Processing Record 48 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 50 of Set 7 | prince rupert
# Processing Record 1 of Set 8 | touros
# Processing Record 2 of Set 8 | asmar
# Processing Record 3 of Set 8 | usakos
# Processing Record 4 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 8 | ambodifototra
# City not found. Skipping...
# Processing Record 6 of Set 8 | port hardy
# Processing Record 7 of Set 8 | havre
# Processing Record 8 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 9 of Set 8 | akdepe
# Processing Record 10 of Set 8 | aygut
# Processing Record 11 of Set 8 | jablunkov
# Processing Record 12 of Set 8 | cheltenham
# Processing Record 13 of Set 8 | malpe
# Processing Record 14 of Set 8 | natal
# Processing Record 15 of Set 8 | nurpur
# Processing Record 16 of Set 8 | crab hill
# City not found. Skipping...
# Processing Record 17 of Set 8 | quatre cocos
# Processing Record 18 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 8 | fasa
# Processing Record 20 of Set 8 | lavrentiya
# Processing Record 21 of Set 8 | salalah
# Processing Record 22 of Set 8 | kita
# Processing Record 23 of Set 8 | bissau
# Processing Record 24 of Set 8 | cherskiy
# Processing Record 25 of Set 8 | eureka
# Processing Record 26 of Set 8 | lusambo
# Processing Record 27 of Set 8 | orbetello
# Processing Record 28 of Set 8 | codrington
# Processing Record 29 of Set 8 | staroderevyankovskaya
# Processing Record 30 of Set 8 | bambanglipuro
# Processing Record 31 of Set 8 | olafsvik
# Processing Record 32 of Set 8 | berlevag
# Processing Record 33 of Set 8 | chokurdakh
# Processing Record 34 of Set 8 | aquiraz
# Processing Record 35 of Set 8 | tikamgarh
# Processing Record 36 of Set 8 | marathon
# Processing Record 37 of Set 8 | solsvik
# City not found. Skipping...
# Processing Record 38 of Set 8 | pahrump
# Processing Record 39 of Set 8 | san cristobal
# Processing Record 40 of Set 8 | alakurtti
# Processing Record 41 of Set 8 | tabas
# Processing Record 42 of Set 8 | clyde river
# Processing Record 43 of Set 8 | auki
# Processing Record 44 of Set 8 | craig
# Processing Record 45 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 46 of Set 8 | koungou
# Processing Record 47 of Set 8 | leh
# Processing Record 48 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 49 of Set 8 | lompoc
# Processing Record 50 of Set 8 | north bend
# Processing Record 1 of Set 9 | touba
# Processing Record 2 of Set 9 | vuktyl
# Processing Record 3 of Set 9 | amurzet
# Processing Record 4 of Set 9 | orzu
# Processing Record 5 of Set 9 | dunabogdany
# Processing Record 6 of Set 9 | saint-denis
# Processing Record 7 of Set 9 | launceston
# Processing Record 8 of Set 9 | bongandanga
# Processing Record 9 of Set 9 | rio gallegos
# Processing Record 10 of Set 9 | vizinga
# Processing Record 11 of Set 9 | tiksi
# Processing Record 12 of Set 9 | halifax
# Processing Record 13 of Set 9 | kulhudhuffushi
# Processing Record 14 of Set 9 | saint-leu
# Processing Record 15 of Set 9 | taksimo
# Processing Record 16 of Set 9 | honiara
# Processing Record 17 of Set 9 | gazli
# Processing Record 18 of Set 9 | nuevo progreso
# Processing Record 19 of Set 9 | yumen
# Processing Record 20 of Set 9 | kavaratti
# Processing Record 21 of Set 9 | trincomalee
# Processing Record 22 of Set 9 | ahuimanu
# Processing Record 23 of Set 9 | athabasca
# Processing Record 24 of Set 9 | oktyabrskoye
# Processing Record 25 of Set 9 | buin
# Processing Record 26 of Set 9 | oum hadjer
# Processing Record 27 of Set 9 | kieta
# Processing Record 28 of Set 9 | north platte
# Processing Record 29 of Set 9 | puerto del rosario
# Processing Record 30 of Set 9 | dum duma
# Processing Record 31 of Set 9 | okhotsk
# Processing Record 32 of Set 9 | bar harbor
# Processing Record 33 of Set 9 | port blair
# Processing Record 34 of Set 9 | anadyr
# Processing Record 35 of Set 9 | inhambane
# Processing Record 36 of Set 9 | klaksvik
# Processing Record 37 of Set 9 | iquique
# Processing Record 38 of Set 9 | boende
# Processing Record 39 of Set 9 | giresun
# Processing Record 40 of Set 9 | bilibino
# Processing Record 41 of Set 9 | nemuro
# Processing Record 42 of Set 9 | kungurtug
# Processing Record 43 of Set 9 | abaza
# Processing Record 44 of Set 9 | abbeville
# Processing Record 45 of Set 9 | meulaboh
# Processing Record 46 of Set 9 | camacupa
# Processing Record 47 of Set 9 | takoradi
# Processing Record 48 of Set 9 | ambon
# Processing Record 49 of Set 9 | hakkari
# Processing Record 50 of Set 9 | guozhen
# Processing Record 1 of Set 10 | yanam
# Processing Record 2 of Set 10 | provideniya
# Processing Record 3 of Set 10 | vardo
# Processing Record 4 of Set 10 | duma
# Processing Record 5 of Set 10 | najran
# Processing Record 6 of Set 10 | bac lieu
# Processing Record 7 of Set 10 | hohhot
# Processing Record 8 of Set 10 | pachino
# Processing Record 9 of Set 10 | mokhotlong
# Processing Record 10 of Set 10 | alofi
# Processing Record 11 of Set 10 | khuzdar
# Processing Record 12 of Set 10 | puerto montt
# Processing Record 13 of Set 10 | salaza
# Processing Record 14 of Set 10 | zaozhuang
# Processing Record 15 of Set 10 | beringovskiy
# Processing Record 16 of Set 10 | falkenstein
# Processing Record 17 of Set 10 | yerbogachen
# Processing Record 18 of Set 10 | filingue
# Processing Record 19 of Set 10 | monte patria
# Processing Record 20 of Set 10 | tabasco
# Processing Record 21 of Set 10 | tuscaloosa
# Processing Record 22 of Set 10 | severo-yeniseyskiy
# Processing Record 23 of Set 10 | jamame
# Processing Record 24 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 25 of Set 10 | dudinka
# Processing Record 26 of Set 10 | ixtapa
# Processing Record 27 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 28 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 29 of Set 10 | panalingaan
# Processing Record 30 of Set 10 | gornyy
# Processing Record 31 of Set 10 | zheleznogorsk
# Processing Record 32 of Set 10 | parrita
# Processing Record 33 of Set 10 | tottori
# Processing Record 34 of Set 10 | saint cloud
# Processing Record 35 of Set 10 | mkushi
# Processing Record 36 of Set 10 | dolzhanskaya
# Processing Record 37 of Set 10 | brae
# Processing Record 38 of Set 10 | rondonopolis
# Processing Record 39 of Set 10 | liberal
# Processing Record 40 of Set 10 | zambezi
# Processing Record 41 of Set 10 | hachinohe
# Processing Record 42 of Set 10 | charters towers
# Processing Record 43 of Set 10 | ambilobe
# Processing Record 44 of Set 10 | hsinhua
# City not found. Skipping...
# Processing Record 45 of Set 10 | stryn
# Processing Record 46 of Set 10 | pangnirtung
# Processing Record 47 of Set 10 | vao
# Processing Record 48 of Set 10 | saint george
# Processing Record 49 of Set 10 | do rud
# City not found. Skipping...
# Processing Record 50 of Set 10 | lata
# Processing Record 1 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 2 of Set 11 | aksarka
# Processing Record 3 of Set 11 | port lincoln
# Processing Record 4 of Set 11 | faanui
# Processing Record 5 of Set 11 | san benito
# Processing Record 6 of Set 11 | portland
# Processing Record 7 of Set 11 | tromso
# Processing Record 8 of Set 11 | comodoro rivadavia
# Processing Record 9 of Set 11 | bosaso
# Processing Record 10 of Set 11 | shenkursk
# Processing Record 11 of Set 11 | tadine
# Processing Record 12 of Set 11 | gandorhun
# Processing Record 13 of Set 11 | seoul
# Processing Record 14 of Set 11 | nizhniy kuranakh
# Processing Record 15 of Set 11 | benjamin constant
# Processing Record 16 of Set 11 | makakilo city
# Processing Record 17 of Set 11 | olavarria
# Processing Record 18 of Set 11 | mansa
# Processing Record 19 of Set 11 | narva-joesuu
# Processing Record 20 of Set 11 | krasnoselkup
# Processing Record 21 of Set 11 | itahari
# City not found. Skipping...
# Processing Record 22 of Set 11 | boundiali
# Processing Record 23 of Set 11 | kacuni
# Processing Record 24 of Set 11 | naze
# Processing Record 25 of Set 11 | verkhovyna
# Processing Record 26 of Set 11 | lazarev
# Processing Record 27 of Set 11 | nuevo ideal
# Processing Record 28 of Set 11 | belaya gora
# Processing Record 29 of Set 11 | mae sot
# Processing Record 30 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 11 | molochnyy
# Processing Record 32 of Set 11 | andselv
# City not found. Skipping...
# Processing Record 33 of Set 11 | sanary-sur-mer
# Processing Record 34 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 11 | porto novo
# Processing Record 36 of Set 11 | rolim de moura
# City not found. Skipping...
# Processing Record 37 of Set 11 | tarakan
# Processing Record 38 of Set 11 | glendive
# Processing Record 39 of Set 11 | huarmey
# Processing Record 40 of Set 11 | machinga
# Processing Record 41 of Set 11 | waddan
# Processing Record 42 of Set 11 | namatanai
# Processing Record 43 of Set 11 | pryazha
# Processing Record 44 of Set 11 | chumphon
# Processing Record 45 of Set 11 | sumter
# Processing Record 46 of Set 11 | weligama
# Processing Record 47 of Set 11 | port-cartier
# Processing Record 48 of Set 11 | douglas
# Processing Record 49 of Set 11 | vorobyevka
# Processing Record 50 of Set 11 | salinas
# Processing Record 1 of Set 12 | wilmington
# Processing Record 2 of Set 12 | port hedland
# Processing Record 3 of Set 12 | saint-pierre
# Processing Record 4 of Set 12 | hasaki
# Processing Record 5 of Set 12 | seabra
# Processing Record 6 of Set 12 | karamea
# City not found. Skipping...
# Processing Record 7 of Set 12 | ust-tsilma
# Processing Record 8 of Set 12 | kidal
# Processing Record 9 of Set 12 | bereda
# Processing Record 10 of Set 12 | milingimbi
# City not found. Skipping...
# Processing Record 11 of Set 12 | mindelo
# Processing Record 12 of Set 12 | arcachon
# Processing Record 13 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 14 of Set 12 | tahta
# Processing Record 15 of Set 12 | mandalgovi
# Processing Record 16 of Set 12 | niquelandia
# Processing Record 17 of Set 12 | nanortalik
# Processing Record 18 of Set 12 | jamundi
# Processing Record 19 of Set 12 | port keats
# Processing Record 20 of Set 12 | fayaoue
# Processing Record 21 of Set 12 | tautira
# Processing Record 22 of Set 12 | banmankhi
# Processing Record 23 of Set 12 | neuquen
# Processing Record 24 of Set 12 | pitimbu
# Processing Record 25 of Set 12 | mizdah
# Processing Record 26 of Set 12 | manoel urbano
# Processing Record 27 of Set 12 | don sak
# Processing Record 28 of Set 12 | florence
# Processing Record 29 of Set 12 | digby
# Processing Record 30 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 31 of Set 12 | ilmajoki
# Processing Record 32 of Set 12 | mehamn
# Processing Record 33 of Set 12 | pleasanton
# Processing Record 34 of Set 12 | mariental
# Processing Record 35 of Set 12 | nouadhibou
# Processing Record 36 of Set 12 | chapais
# Processing Record 37 of Set 12 | selikhino
# Processing Record 38 of Set 12 | kuandian
# Processing Record 39 of Set 12 | tamandare
# Processing Record 40 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 41 of Set 12 | cabedelo
# Processing Record 42 of Set 12 | burnie
# Processing Record 43 of Set 12 | saryshagan
# City not found. Skipping...
# Processing Record 44 of Set 12 | general pico
# Processing Record 45 of Set 12 | los llanos de aridane
# Processing Record 46 of Set 12 | jaciara
# Processing Record 47 of Set 12 | lokomotivnyy
# Processing Record 48 of Set 12 | gawler
# Processing Record 49 of Set 12 | andenes
# Processing Record 50 of Set 12 | moree
# Processing Record 1 of Set 13 | san jeronimo
# Processing Record 2 of Set 13 | sapa
# Processing Record 3 of Set 13 | bolshiye uki
# City not found. Skipping...
# Processing Record 4 of Set 13 | kaeo
# Processing Record 5 of Set 13 | xiaoweizhai
# Processing Record 6 of Set 13 | khandyga
# Processing Record 7 of Set 13 | rocha
# Processing Record 8 of Set 13 | ati
# Processing Record 9 of Set 13 | khormuj
# City not found. Skipping...
# Processing Record 10 of Set 13 | sembakung
# Processing Record 11 of Set 13 | noyabrsk
# Processing Record 12 of Set 13 | lope de vega
# Processing Record 13 of Set 13 | uniontown
# Processing Record 14 of Set 13 | nelson bay
# Processing Record 15 of Set 13 | miquelon
# Processing Record 16 of Set 13 | paita
# Processing Record 17 of Set 13 | minsk
# Processing Record 18 of Set 13 | puerto escondido
# Processing Record 19 of Set 13 | hauterive
# Processing Record 20 of Set 13 | tigzirt
# Processing Record 21 of Set 13 | palatka
# Processing Record 22 of Set 13 | coquimbo
# Processing Record 23 of Set 13 | alto vera
# City not found. Skipping...
# Processing Record 24 of Set 13 | acapulco
# Processing Record 25 of Set 13 | haines junction
# Processing Record 26 of Set 13 | simao
# Processing Record 27 of Set 13 | scottsburgh
# City not found. Skipping...
# Processing Record 28 of Set 13 | inyonga
# Processing Record 29 of Set 13 | taburi
# City not found. Skipping...
# Processing Record 30 of Set 13 | toftlund
# Processing Record 31 of Set 13 | alamosa
# Processing Record 32 of Set 13 | huacho
# Processing Record 33 of Set 13 | talnakh
# Processing Record 34 of Set 13 | riachao das neves
# Processing Record 35 of Set 13 | kalmar
# Processing Record 36 of Set 13 | kangundo
# Processing Record 37 of Set 13 | pasni
# Processing Record 38 of Set 13 | key west
# Processing Record 39 of Set 13 | mahajanga
# Processing Record 40 of Set 13 | utete
# Processing Record 41 of Set 13 | alto baudo
# City not found. Skipping...
# Processing Record 42 of Set 13 | xichang
# Processing Record 43 of Set 13 | lleida
# Processing Record 44 of Set 13 | chumikan
# Processing Record 45 of Set 13 | gryazovets
# Processing Record 46 of Set 13 | southampton
# Processing Record 47 of Set 13 | talcahuano
# Processing Record 48 of Set 13 | stratford-upon-avon
# Processing Record 49 of Set 13 | petropavlivka
# Processing Record 50 of Set 13 | belyy yar
# Processing Record 1 of Set 14 | pimentel
# Processing Record 2 of Set 14 | patacamaya
# Processing Record 3 of Set 14 | fort frances
# Processing Record 4 of Set 14 | ape
# Processing Record 5 of Set 14 | kisangani
# Processing Record 6 of Set 14 | birjand
# Processing Record 7 of Set 14 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 8 of Set 14 | vestmannaeyjar
# Processing Record 9 of Set 14 | san juan de arama
# Processing Record 10 of Set 14 | verkh-usugli
# Processing Record 11 of Set 14 | arman
# Processing Record 12 of Set 14 | cam ranh
# Processing Record 13 of Set 14 | gorontalo
# Processing Record 14 of Set 14 | monster
# Processing Record 15 of Set 14 | pangody
# Processing Record 16 of Set 14 | chulman
# Processing Record 17 of Set 14 | dingle
# Processing Record 18 of Set 14 | kununurra
# Processing Record 19 of Set 14 | manta
# Processing Record 20 of Set 14 | ushtobe
# Processing Record 21 of Set 14 | obihiro
# Processing Record 22 of Set 14 | otofuke
# Processing Record 23 of Set 14 | gravdal
# Processing Record 24 of Set 14 | sirawai
# Processing Record 25 of Set 14 | muros
# Processing Record 26 of Set 14 | motril
# Processing Record 27 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 28 of Set 14 | libreville
# Processing Record 29 of Set 14 | sheregesh
# Processing Record 30 of Set 14 | kudahuvadhoo
# Processing Record 31 of Set 14 | skjervoy
# Processing Record 32 of Set 14 | ankazoabo
# Processing Record 33 of Set 14 | road town
# Processing Record 34 of Set 14 | samana
# Processing Record 35 of Set 14 | dzhida
# Processing Record 36 of Set 14 | mitsamiouli
# Processing Record 37 of Set 14 | porgera
# Processing Record 38 of Set 14 | xicotencatl
# Processing Record 39 of Set 14 | artyom
# Processing Record 40 of Set 14 | dinard
# Processing Record 41 of Set 14 | ferrieres
# Processing Record 42 of Set 14 | chabahar
# Processing Record 43 of Set 14 | yomitan
# City not found. Skipping...
# Processing Record 44 of Set 14 | alpena
# Processing Record 45 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 46 of Set 14 | surgut
# Processing Record 47 of Set 14 | ghanzi
# Processing Record 48 of Set 14 | jacmel
# Processing Record 49 of Set 14 | lerwick
# Processing Record 50 of Set 14 | beira
# Processing Record 1 of Set 15 | peniche
# Processing Record 2 of Set 15 | challans
# Processing Record 3 of Set 15 | san vicente
# Processing Record 4 of Set 15 | mount pleasant
# Processing Record 5 of Set 15 | ola
# Processing Record 6 of Set 15 | diamantino
# Processing Record 7 of Set 15 | usinsk
# Processing Record 8 of Set 15 | port shepstone
# Processing Record 9 of Set 15 | tuxtla
# Processing Record 10 of Set 15 | shache
# Processing Record 11 of Set 15 | dzhusaly
# City not found. Skipping...
# Processing Record 12 of Set 15 | muragachha
# City not found. Skipping...
# Processing Record 13 of Set 15 | sao borja
# Processing Record 14 of Set 15 | alyangula
# Processing Record 15 of Set 15 | ferme-neuve
# Processing Record 16 of Set 15 | inuvik
# Processing Record 17 of Set 15 | hailar
# Processing Record 18 of Set 15 | yining
# Processing Record 19 of Set 15 | padang
# Processing Record 20 of Set 15 | pedasi
# Processing Record 21 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 22 of Set 15 | upata
# Processing Record 23 of Set 15 | kloulklubed
# Processing Record 24 of Set 15 | mocuba
# Processing Record 25 of Set 15 | lalian
# Processing Record 26 of Set 15 | gorin
# Processing Record 27 of Set 15 | skelleftea
# Processing Record 28 of Set 15 | zolotinka
# City not found. Skipping...
# Processing Record 29 of Set 15 | lapao
# Processing Record 30 of Set 15 | ugoofaaru
# Processing Record 31 of Set 15 | akhmim
# Processing Record 32 of Set 15 | kebemer
# City not found. Skipping...
# Processing Record 33 of Set 15 | green valley
# Processing Record 34 of Set 15 | uray
# Processing Record 35 of Set 15 | kondinskoye
# Processing Record 36 of Set 15 | rovaniemi
# Processing Record 37 of Set 15 | birao
# Processing Record 38 of Set 15 | kenai
# Processing Record 39 of Set 15 | nam tha
# City not found. Skipping...
# Processing Record 40 of Set 15 | oranjestad
# Processing Record 41 of Set 15 | coihaique
# Processing Record 42 of Set 15 | beboto
# Processing Record 43 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 15 | gondanglegi
# Processing Record 45 of Set 15 | villazon
# Processing Record 46 of Set 15 | poltavka
# Processing Record 47 of Set 15 | chara
# Processing Record 48 of Set 15 | tatawin
# Processing Record 49 of Set 15 | puerto colombia
# Processing Record 50 of Set 15 | freudenstadt
# Processing Record 1 of Set 16 | mildura
# Processing Record 2 of Set 16 | jacareacanga
# Processing Record 3 of Set 16 | mananjary
# Processing Record 4 of Set 16 | suleja
# Processing Record 5 of Set 16 | macaboboni
# City not found. Skipping...
# Processing Record 6 of Set 16 | vila velha
# Processing Record 7 of Set 16 | coahuayana
# Processing Record 8 of Set 16 | kuching
# Processing Record 9 of Set 16 | pueblo nuevo
# Processing Record 10 of Set 16 | yatou
# Processing Record 11 of Set 16 | vredendal
# Processing Record 12 of Set 16 | dawlatabad
# Processing Record 13 of Set 16 | poplar bluff
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 693

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Rikitea -23.1203 -134.9692     76.68        77          15
# 1  Sao Joao Da Barra -21.6403  -41.0511     74.17        91           8
# 2         Oranjemund -28.5500   16.4333     61.50        96          61
# 3              Lagoa  39.0500  -27.9833     62.89        94         100
# 4            Mataura -46.1927  168.8643     63.48        67         100
# 5            Qaanaaq  77.4840  -69.3632      5.81        81         100
# 6              Wagar  16.1525   36.2032     69.55        80           0
# 7              Tabou   4.4230   -7.3528     78.57        84           1
# 8              Bluff -46.6000  168.3333     63.81        81          68
# 9             Barrow  71.2906 -156.7887      8.62        78         100
#
#    Wind Speed Country                 Date Current Description
# 0       13.53      PF  2022-12-10 01:40:43          few clouds
# 1        7.23      BR  2022-12-10 01:40:44           clear sky
# 2        3.13      NA  2022-12-10 01:40:44       broken clouds
# 3       42.43      PT  2022-12-10 01:40:44          light rain
# 4        5.91      NZ  2022-12-10 01:40:45     overcast clouds
# 5        1.45      GL  2022-12-10 01:40:45     overcast clouds
# 6       12.15      SD  2022-12-10 01:40:46           clear sky
# 7        7.05      CI  2022-12-10 01:40:46           clear sky
# 8       10.16      NZ  2022-12-10 01:40:46       broken clouds
# 9       17.27      US  2022-12-10 01:39:36     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0            Rikitea      PF -23.1203 -134.9692     76.68        77
# 1  Sao Joao Da Barra      BR -21.6403  -41.0511     74.17        91
# 2         Oranjemund      NA -28.5500   16.4333     61.50        96
# 3              Lagoa      PT  39.0500  -27.9833     62.89        94
# 4            Mataura      NZ -46.1927  168.8643     63.48        67
# 5            Qaanaaq      GL  77.4840  -69.3632      5.81        81
# 6              Wagar      SD  16.1525   36.2032     69.55        80
# 7              Tabou      CI   4.4230   -7.3528     78.57        84
# 8              Bluff      NZ -46.6000  168.3333     63.81        81
# 9             Barrow      US  71.2906 -156.7887      8.62        78
#
#    Cloudiness Current Description
# 0          15          few clouds
# 1           8           clear sky
# 2          61       broken clouds
# 3         100          light rain
# 4         100     overcast clouds
# 5         100     overcast clouds
# 6           0           clear sky
# 7           1           clear sky
# 8          68       broken clouds
# 9         100     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
weatherpy_output_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(weatherpy_output_file, index_label="City_Name")
