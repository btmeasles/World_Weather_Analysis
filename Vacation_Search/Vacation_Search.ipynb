# %% [markdown]
# # Deliverable 2. Create a Customer Travel Destinations Map
#
# ----
#
# 1. Create a folder called `Vacation_Search` to save all the files related with this deliverable.
#
# 2. Download the `Vacation_Search_starter_code.ipynb` Jupyter notebook,save it into your `Vacation_Search folder`, and rename it as `Vacation_Search.ipynb`.
#
# 3. In the `Vacation_Search.ipynb` file, ensure that the dependencies and the Geoapify API key is imported correctly.
#
# 4. From the `Weather_Database` folder you created in the "Deliverable 1," import the `WeatherPy_Database.csv` file as a Pandas DataFrame named `city_data_df`.
#
# 5. Write two input statements that prompt the user to enter their minimum and maximum temperature criteria for their vacation.
#
# 6. Create a new Pandas DataFrame by using the `loc` Pandas method to filter the `city_data_df` DataFrame for temperature criteria  collected. Name the DataFrame as `preferred_cities_df`.
#
# 7. Create a new Pandas DataFrame named `clean_travel_cities` by using the Pandas `dropna` function on the `preferred_cities_df` to drop any empty rows.
#
# 8. Use the `copy` Pandas function to create a new DataFrame, called `hotel_df`, by copying the following columns from the `clean_travel_cities` DataFrame: "City", "Country", "Max Temp", "Current Description", "Lat", "Lng".
#
# 9. Add a new empty column named `Hotel Name` to the `hotel_df` DataFrame.
#
# 10. Review the hotel search parameters provided. These parameters are the same we used in this module; you'll use them to search for a hotel for each city.
#
# 11. Use a for loop to iterate through the `hotel_df` DataFrame. Retrieve the latitude and longitude of each city and use the Geoapify API to find the nearest hotel based on the search parameters provided, then add the hotel name to the `hotel_df` DataFrame. If a hotel isn't found, set the hotel name as "No hotel found".
#
# 12. Drop any rows in the `hotel_df` DataFrame where a hotel name is not found and store the resulting data into a new DataFrame named `clean_hotel_df`.
#
# 13. Create an CSV file to store the `clean_hotel_df` DataFrame as `WeatherPy_vacation.csv` in the Vacation_Search folder.
#
# 14. Use GeoViews to create a map that displays a point for every city in the `clean_hotel_df` DataFrame. In the point for each city add:
#
#     * The city name
#
#     * The country code
#
#     * The weather description
#
#     * The point's size should be the maximum temperature for the city
#
# 15. Take a screenshot of your map and save it to the `Vacation_Search` folder as `WeatherPy_vacation_map.png`.
#
# ---

# %% [markdown]
# ## Ensure that the dependencies and the Geoapify API key is imported correctly

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")

# Import API key
from config import geoapify_key

# %% [markdown]
# ## From the `Weather_Database` folder you created in the "Deliverable 1," import the `WeatherPy_Database.csv` file as a Pandas DataFrame named `city_data_df`

# %%
# Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("../Weather_Database/WeatherPy_Database.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_Name               City Country      Lat       Lng  Max Temp  \
# 0          0            Rikitea      PF -23.1203 -134.9692     76.68
# 1          1  Sao Joao Da Barra      BR -21.6403  -41.0511     74.17
# 2          2         Oranjemund     NaN -28.5500   16.4333     61.50
# 3          3              Lagoa      PT  39.0500  -27.9833     62.89
# 4          4            Mataura      NZ -46.1927  168.8643     63.48
#
#    Humidity  Cloudiness Current Description
# 0        77          15          few clouds
# 1        91           8           clear sky
# 2        96          61       broken clouds
# 3        94         100          light rain
# 4        67         100     overcast clouds

# %% [markdown]
# ## Write two input statements that prompt the user to enter their minimum and maximum temperature criteria for their vacation

# %%
# Prompt the user to enter minimum and maximum temperature criteria.
min_temp = float(input("What is the minimum temperature you like for your trip?  "))
max_temp = float(input("What is the maximum temperature you like for your trip?  "))
print("What is the minimum temperature you like for your trip?", min_temp)
print("What is the maximum temperature you like for your trip?", max_temp)
# Out:
# What is the minimum temperature you like for your trip? 10.0
# What is the maximum temperature you like for your trip? 50.0

# %% [markdown]
# ## Create a new Pandas DataFrame by using the `loc` Pandas method to filter the `city_data_df` DataFrame for temperature criteria  collected. Name the DataFrame as `preferred_cities_df`

# %%
# Filter the city_data_df DataFrame to find the cities that fit the criteria using the loc method.
preferred_cities_df = city_data_df.loc[
    (city_data_df['Max Temp'] <= max_temp) & (city_data_df["Max Temp"] >= min_temp)
    ]

# Display sample data
preferred_cities_df.head(10)
# Out:
#     City_Name          City Country      Lat       Lng  Max Temp  Humidity  \
# 14         14          Lasa      IT  46.6166   10.7002     31.03        97
# 16         16        Albany      US  42.6001  -73.9662     28.40        61
# 28         28        Juneau      US  58.3019 -134.4197     32.22        93
# 31         31     Jamestown      US  42.0970  -79.2353     29.01        66
# 32         32       Margate      GB  51.3813    1.3862     30.31        91
# 33         33      Tasiilaq      GL  65.6145  -37.6368     23.16        59
# 34         34       Ushuaia      AR -54.8000  -68.3000     44.26        65
# 35         35        Witney      GB  51.7836   -1.4854     32.29        93
# 45         45  Longyearbyen      SJ  78.2186   15.6401     21.04        79
# 51         51  Punta Arenas      CL -53.1500  -70.9167     48.31        61
#
#     Cloudiness Current Description
# 14         100     overcast clouds
# 16           0           clear sky
# 28          75       broken clouds
# 31           0           clear sky
# 32          27    scattered clouds
# 33          33    scattered clouds
# 34          40    scattered clouds
# 35           0                mist
# 45          40    scattered clouds
# 51          40    scattered clouds

# %% [markdown]
# ## Create a new Pandas DataFrame named `clean_travel_cities` by using the Pandas `dropna` function on the `preferred_cities_df` to drop any empty rows

# %%
# Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
clean_travel_cities = preferred_cities_df.dropna()

# Display sample data
clean_travel_cities.head(10)
# Out:
#     City_Name          City Country      Lat       Lng  Max Temp  Humidity  \
# 14         14          Lasa      IT  46.6166   10.7002     31.03        97
# 16         16        Albany      US  42.6001  -73.9662     28.40        61
# 28         28        Juneau      US  58.3019 -134.4197     32.22        93
# 31         31     Jamestown      US  42.0970  -79.2353     29.01        66
# 32         32       Margate      GB  51.3813    1.3862     30.31        91
# 33         33      Tasiilaq      GL  65.6145  -37.6368     23.16        59
# 34         34       Ushuaia      AR -54.8000  -68.3000     44.26        65
# 35         35        Witney      GB  51.7836   -1.4854     32.29        93
# 45         45  Longyearbyen      SJ  78.2186   15.6401     21.04        79
# 51         51  Punta Arenas      CL -53.1500  -70.9167     48.31        61
#
#     Cloudiness Current Description
# 14         100     overcast clouds
# 16           0           clear sky
# 28          75       broken clouds
# 31           0           clear sky
# 32          27    scattered clouds
# 33          33    scattered clouds
# 34          40    scattered clouds
# 35           0                mist
# 45          40    scattered clouds
# 51          40    scattered clouds

# %% [markdown]
# ## Use the `copy` Pandas function to create a new DataFrame, called `hotel_df`, by copying the following columns from the `clean_travel_cities` DataFrame: "City", "Country", "Max Temp", "Current Description", "Lat", "Lng"

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_travel_cities[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# %% [markdown]
# ## Add a new empty column named `Hotel Name` to the `hotel_df` DataFrame

# %%
# Create a new column "Hotel Name".
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df.head()
# Out:
#          City Country  Max Temp Current Description      Lat       Lng  \
# 14       Lasa      IT     31.03     overcast clouds  46.6166   10.7002
# 16     Albany      US     28.40           clear sky  42.6001  -73.9662
# 28     Juneau      US     32.22       broken clouds  58.3019 -134.4197
# 31  Jamestown      US     29.01           clear sky  42.0970  -79.2353
# 32    Margate      GB     30.31    scattered clouds  51.3813    1.3862
#
#    Hotel Name
# 14
# 16
# 28
# 31
# 32

# %% [markdown]
# ## Review the hotel search parameters provided. These parameters are the same we used in this module; you'll use them to search for a hotel for each city

# %%
# Set parameters to search for a hotel
radius = 5000
params = {
    "categories":"accommodation.hotel",
    "apiKey": geoapify_key,
    "limit":20
}

# %% [markdown]
# ## Use a for loop to iterate through the `hotel_df` DataFrame. Retrieve the latitude and longitude of each city and use the Geoapify API to find the nearest hotel based on the search parameters provided, then add the hotel name to the `hotel_df` DataFrame. If a hotel isn't found, set the hotel name as "No hotel found"

# %%
# Iterate through the hotel DataFrame

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # Get latitude and longitude from DataFrame.
    latitude = row["Lat"]
    longitude = row["Lng"]
    
    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set up the base URL for the Geoapify Places API.
    base_url = "https://api.geoapify.com/v2/places"

    # Make request and retrieve the JSON data by using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Get the first hotel from the results and store the name, if a hotel isn't found set the hotel name as "No hotel found".
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# Lasa - nearest hotel: Hotel "Drei Kreuz"
# Albany - nearest hotel: No hotel found
# Juneau - nearest hotel: Ramada by Wyndham Juneau
# Jamestown - nearest hotel: DoubleTree Jamestown
# Margate - nearest hotel: The Reading Rooms
# Tasiilaq - nearest hotel: Angmagssalik
# Ushuaia - nearest hotel: Apart Hotel Aires del Beagle
# Witney - nearest hotel: The Witney Hotel
# Longyearbyen - nearest hotel: The Vault
# Punta Arenas - nearest hotel: Hotel Lacolet
# Greencastle - nearest hotel: Inn at DePauw
# Thompson - nearest hotel: Thompson Inn
# Nikolskoye - nearest hotel: No hotel found
# Kodiak - nearest hotel: Shelikof Lodge
# Atikokan - nearest hotel: No hotel found
# Redcar - nearest hotel: Claxton House Hotel
# Ostrovnoy - nearest hotel: No hotel found
# Ilulissat - nearest hotel: Best Western Plus Hotel Ilulissat
# Severo-Kurilsk - nearest hotel: "Дом рыбака"
# Fredericksburg - nearest hotel: Kenmore Inn
# Jumla - nearest hotel: Amar Sandesh Guesthouse
# Torbay - nearest hotel: No hotel found
# Manitouwadge - nearest hotel: No hotel found
# Upernavik - nearest hotel: No hotel found
# Hamilton - nearest hotel: North Vista Manor
# Raahe - nearest hotel: Aparthotel Forenom
# Komsomolskiy - nearest hotel: Hotel "Ikat House"
# Nome - nearest hotel: No hotel found
# Hami - nearest hotel: No hotel found
# Ufimskiy - nearest hotel: No hotel found
# Szczytno - nearest hotel: Hotel Krystyna
# Westport - nearest hotel: Norwalk Inn and Conference Center
# Butler - nearest hotel: No hotel found
# Sobolevo - nearest hotel: No hotel found
# Korla - nearest hotel: Silver Star Hotel
# Fortuna - nearest hotel: Comfort Inn & Suites Redwood Country
# Ucar - nearest hotel: Otel
# Mayo - nearest hotel: No hotel found
# Havre-Saint-Pierre - nearest hotel: Complexe MV
# Escanaba - nearest hotel: Magnuson Grand Pioneer Inn and Suites
# Bethel - nearest hotel: Hampton Inn Danbury
# Fairbanks - nearest hotel: Westmark Fairbanks Hotel
# Whitley Bay - nearest hotel: Dunes Hotel
# Kashi - nearest hotel: 深航国际酒店
# Yoichi - nearest hotel: No hotel found
# Den Helder - nearest hotel: Forest Hotel
# Kristiinankaupunki - nearest hotel: Hotel Alma
# Zhangye - nearest hotel: Zhangye Hotel 张掖饭店
# Qasigiannguit - nearest hotel: Hotel Diskobay
# Dryden - nearest hotel: Holiday Inn Express
# Weinan - nearest hotel: No hotel found
# Yuksekova - nearest hotel: Hotel Oslo
# Svetlyy - nearest hotel: No hotel found
# Pendleton - nearest hotel: Working Girls Hotel
# Narsaq - nearest hotel: Hotel Narsaq
# Palmer - nearest hotel: No hotel found
# Sauda - nearest hotel: Mettes Lille Hotell
# Maniitsoq - nearest hotel: Hotel Heilmann Lyberth
# Rassvet - nearest hotel: No hotel found
# Sterling - nearest hotel: Residence Inn by Marriott Dulles Airport at Dulles 28 Centre
# Kuryk - nearest hotel: Kuryk
# Banepa - nearest hotel: rajendra
# Terney - nearest hotel: Терней
# Kropotkin - nearest hotel: Европа
# Asau - nearest hotel: No hotel found
# Bud - nearest hotel: No hotel found
# Brooks - nearest hotel: No hotel found
# Kitakata - nearest hotel: 笹屋旅館
# Nipawin - nearest hotel: No hotel found
# College - nearest hotel: BEST WESTERN PLUS Pioneer Park Inn
# Grindavik - nearest hotel: The Retreat at Blue Lagoon Iceland
# Basqal - nearest hotel: No hotel found
# Sitka - nearest hotel: Aspen Suites Hotel
# Great Yarmouth - nearest hotel: Classic Lodge
# Ventspils - nearest hotel: Dzintarjūra
# Ukiah - nearest hotel: Palace Hotel
# Saint-Jean-De-Maurienne - nearest hotel: No hotel found
# Bad Nauheim - nearest hotel: Rex
# Prince Rupert - nearest hotel: Crest Hotel
# Asmar - nearest hotel: No hotel found
# Port Hardy - nearest hotel: No hotel found
# Havre - nearest hotel: No hotel found
# Aygut - nearest hotel: No hotel found
# Jablunkov - nearest hotel: Hotel Bullawa
# Cheltenham - nearest hotel: George Hotel
# Fasa - nearest hotel: No hotel found
# Lavrentiya - nearest hotel: Фортуна
# Eureka - nearest hotel: Eureka Inn, Trademark Collection by Wyndham
# Staroderevyankovskaya - nearest hotel: Колос
# Olafsvik - nearest hotel: North Star Hotel Snæfellsnes
# Berlevag - nearest hotel: No hotel found
# Marathon - nearest hotel: No hotel found
# Pahrump - nearest hotel: Holiday Inn Express & Suites
# Alakurtti - nearest hotel: No hotel found
# Tabas - nearest hotel: هتل امیر
# Craig - nearest hotel: Quality Inn & Suites
# Leh - nearest hotel: Kang Lha Chen
# Orzu - nearest hotel: No hotel found
# Dunabogdany - nearest hotel: Bonifert Panzió
# Saint-Denis - nearest hotel: Hôtel de France
# Vizinga - nearest hotel: Надежда
# Halifax - nearest hotel: Four Points by Sheraton Halifax
# Gazli - nearest hotel: No hotel found
# Yumen - nearest hotel: No hotel found
# Oktyabrskoye - nearest hotel: No hotel found
# North Platte - nearest hotel: Ramada
# Bar Harbor - nearest hotel: Acadia Hotel
# Anadyr - nearest hotel: Гостевой дом
# Klaksvik - nearest hotel: Hotel Klaksvik
# Giresun - nearest hotel: No hotel found
# Nemuro - nearest hotel: イーストハーバーホテル
# Abbeville - nearest hotel: Hôtel Mercure
# Hakkari - nearest hotel: No hotel found
# Guozhen - nearest hotel: No hotel found
# Provideniya - nearest hotel: No hotel found
# Vardo - nearest hotel: Meieriet
# Duma - nearest hotel: No hotel found
# Zaozhuang - nearest hotel: 枣庄大酒店
# Beringovskiy - nearest hotel: No hotel found
# Falkenstein - nearest hotel: Zur Sonne
# Zheleznogorsk - nearest hotel: Гостиница Железногорск
# Saint Cloud - nearest hotel: Courtyard
# Dolzhanskaya - nearest hotel: No hotel found
# Brae - nearest hotel: Brae Hotel
# Liberal - nearest hotel: Days Inn
# Hachinohe - nearest hotel: スーパーホテル
# Stryn - nearest hotel: Stryn Hotel
# Saint George - nearest hotel: The Advenire, an Autograph Collection Hotel
# San Benito - nearest hotel: No hotel found
# Portland - nearest hotel: the Hoxton
# Tromso - nearest hotel: Clarion Collection Hotel Aurora
# Shenkursk - nearest hotel: No hotel found
# Seoul - nearest hotel: 뉴국제호텔
# Narva-Joesuu - nearest hotel: YES Hotel
# Verkhovyna - nearest hotel: Гуцульський припочівок
# Molochnyy - nearest hotel: No hotel found
# Glendive - nearest hotel: La Quinta Inn & Suites by Wyndham Glendive
# Pryazha - nearest hotel: Пряжа
# Port-Cartier - nearest hotel: No hotel found
# Douglas - nearest hotel: Residence Inn Omaha West
# Vorobyevka - nearest hotel: No hotel found
# Bereda - nearest hotel: No hotel found
# Arcachon - nearest hotel: All Suites
# Nanortalik - nearest hotel: Kap Farvel
# Digby - nearest hotel: Digby Backpackers Inn
# Ilmajoki - nearest hotel: No hotel found
# Mehamn - nearest hotel: Mehamn Arctic hotell
# Kuandian - nearest hotel: No hotel found
# Andenes - nearest hotel: Andrikken hotell
# Xiaoweizhai - nearest hotel: No hotel found
# Uniontown - nearest hotel: Heritage Inn
# Miquelon - nearest hotel: No hotel found
# Minsk - nearest hotel: Европа
# Hauterive - nearest hotel: Auberge Bourbonnaise
# Haines Junction - nearest hotel: Parkside Inn
# Toftlund - nearest hotel: Frosch's Hotel
# Alamosa - nearest hotel: 40 Winks Inn
# Kalmar - nearest hotel: Frimurarehotellet
# Gryazovets - nearest hotel: Дружба
# Southampton - nearest hotel: Travelodge
# Stratford-Upon-Avon - nearest hotel: The Shakespeare
# Petropavlivka - nearest hotel: No hotel found
# Patacamaya - nearest hotel: Hostal Viña del Mar
# Fort Frances - nearest hotel: The Rambler
# Birjand - nearest hotel: مهمانسرای جهانگردی بیرجند
# Vestmannaeyjar - nearest hotel: Hotel Vestmannaeyjar
# Verkh-Usugli - nearest hotel: No hotel found
# Monster - nearest hotel: Fletcher Hotel-Restaurant Elzenduin
# Obihiro - nearest hotel: コンフォートホテル帯広
# Otofuke - nearest hotel: No hotel found
# Gravdal - nearest hotel: No hotel found
# Muros - nearest hotel: Pensión Ría de Muros
# Skjervoy - nearest hotel: Hotel Maritim Skjervøy
# Artyom - nearest hotel: No hotel found
# Dinard - nearest hotel: Les Tilleuls
# Ferrieres - nearest hotel: Au Vieux Logis
# Alpena - nearest hotel: Ramada of Alpena
# Lerwick - nearest hotel: Grand Hotel
# Challans - nearest hotel: Le Challans
# Shache - nearest hotel: 莎車新盛賓舘
# Ferme-Neuve - nearest hotel: Auberge Chez Isaïe
# Skelleftea - nearest hotel: Hotel Victoria
# Rovaniemi - nearest hotel: Matkustajakoti Outa
# Kenai - nearest hotel: Beluga Lookout Hotel
# Freudenstadt - nearest hotel: Gut Lauterbad
# Yatou - nearest hotel: No hotel found
# Dawlatabad - nearest hotel: No hotel found
#              City Country  Max Temp Current Description      Lat       Lng  \
# 14           Lasa      IT     31.03     overcast clouds  46.6166   10.7002
# 16         Albany      US     28.40           clear sky  42.6001  -73.9662
# 28         Juneau      US     32.22       broken clouds  58.3019 -134.4197
# 31      Jamestown      US     29.01           clear sky  42.0970  -79.2353
# 32        Margate      GB     30.31    scattered clouds  51.3813    1.3862
# ..            ...     ...       ...                 ...      ...       ...
# 668     Rovaniemi      FI     18.81     overcast clouds  66.5000   25.7167
# 670         Kenai      US     16.14           clear sky  60.5544 -151.2583
# 680  Freudenstadt      DE     27.63     overcast clouds  48.4333    8.4167
# 689         Yatou      CN     41.56          light rain  37.1500  122.3833
# 691    Dawlatabad      AF     29.07           clear sky  36.4141   64.9053
#
#                    Hotel Name
# 14         Hotel "Drei Kreuz"
# 16             No hotel found
# 28   Ramada by Wyndham Juneau
# 31       DoubleTree Jamestown
# 32          The Reading Rooms
# ..                        ...
# 668       Matkustajakoti Outa
# 670      Beluga Lookout Hotel
# 680             Gut Lauterbad
# 689            No hotel found
# 691            No hotel found
#
# [187 rows x 7 columns]

# %% [markdown]
# ## Drop any rows in the `hotel_df` DataFrame where a hotel name is not found and store the resulting data into a new DataFrame named `clean_hotel_df`

# %%
# Drop the rows where there is no Hotel Name.
clean_hotel_df = hotel_df.drop(index=hotel_df[hotel_df["Hotel Name"] == "No hotel found"].index)

# Display sample data
# Comparison to make sure it worked...
print("Original df missing names", hotel_df.loc[hotel_df["Hotel Name"] == "No hotel found"].count())

print("New df with clean values", clean_hotel_df.loc[clean_hotel_df["Hotel Name"] == "No hotel found"].count())
# Out:
# Original df missing names City                   60
# Country                60
# Max Temp               60
# Current Description    60
# Lat                    60
# Lng                    60
# Hotel Name             60
# dtype: int64
# New df with clean values City                   0
# Country                0
# Max Temp               0
# Current Description    0
# Lat                    0
# Lng                    0
# Hotel Name             0
# dtype: int64

# %% [markdown]
# ## Create an CSV file to store the `clean_hotel_df` DataFrame as `WeatherPy_vacation.csv` in the `Vacation_Search`` folder

# %%
# Create the output File (CSV)
vacation_output_file = "WeatherPy_vacation.csv"

# Export the City_Data into a csv
clean_hotel_df.to_csv(vacation_output_file, index="City_Name")

# %% [markdown]
# ## Use GeoViews to create a map that displays a point for every city in the `clean_hotel_df` DataFrame.
#
# In the point for each city add:
#
# * The city name
# * The country code
# * The weather description
# * The point's size should be the maximum temperature for the city

# %%
# Configure the map plot
hotel_map = clean_hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo=True,
    tiles="OSM",
    title="Hotels in Temp (F) ranging from 10 - 50 degrees",
    frame_height=500,
    frame_width=800,
    size="Max Temp",
    scale=1,
    color="City",
    hover_cols = ["City","Country","Current Description"]
)

# Display the map
hotel_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Max Temp,Country,Current Description)
